# %% [markdown]
# # Generar archivos a partir de base de preguntas

# %% [markdown]
# ### Algunas variables y pasos previos

# %%
# archivos a generar en este notebook
gen_etiquetas = False
gen_sinonimos = False
gen_arbol = True

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import pandas as pd
df1 = pd.read_csv('Etiquetas_diabetes.tsv', sep='\t')
df1.sample(5)
# Out:
#       2q Etiqueta 1            Etiqueta 2          Etiqueta 3 keyword1  \
# 403  326   Diabetes                   NaN                 NaN      NaN
# 78    19   Diabetes  Diabetes Gestacional  Complicaciones D.G      NaN
# 69   148   Diabetes              Diabetes                 NaN      NaN
# 167  169   Diabetes                  Piel                 NaN      NaN
# 384  326   Diabetes                   NaN                 NaN      NaN
#
#     keyword2  keyword3  keyword4 keyword5  \
# 403      NaN       NaN       NaN      NaN
# 78       NaN       NaN       NaN      NaN
# 69       NaN       NaN       NaN      NaN
# 167      NaN       NaN       NaN      NaN
# 384      NaN       NaN       NaN      NaN
#
#                                               Pregunta  \
# 403  Una persona con diabetes Tipo II y en tratamie...
# 78          ¿Cómo me afectará la diabetes gestacional?
# 69   ¿Es posible que una diabetes sin diagnosticar ...
# 167  Que infecciones por bacterias son mas comnunes...
# 384  Quedé diabético tipo 2 después de un tratamien...
#
#                                              Respuesta               Fuente
# 403  En ayunas, entre 70 y 100 mg/dl. Una hora Desp...                  NaN
# 78   Es posible que la diabetes gestacional aumente...        niddk.nih.gov
# 69   Si una de los sintomas de la diabetes es el au...  juntadeandalucia.es
# 167  Se presentan varios tipos de infecciones con b...         diabetes,org
# 384                                                NaN                  NaN

# %%
# encontrar numero de columnas keyword y etiqueta
max_keys = 0
max_labels = 0
while True:
    try:
        max_keys += 1
        df1['keyword'+str(max_keys)]
    except:
        max_keys -= 1
        break
        
while True:
    try:
        max_labels += 1
        df1['Etiqueta '+str(max_labels)]
    except:
        max_labels -= 1
        break
print("Cantidad de columnas encontradas. Keyword: {}. Etiquetas: {}".format(max_keys, max_labels))
# Out:
# Cantidad de columnas encontradas. Keyword: 5. Etiquetas: 3

# %% [markdown]
# ### 1. Pares de keywords y etiquetas

# %%
df1.head()
# Out:
#     2q Etiqueta 1          Etiqueta 2 Etiqueta 3               keyword1  \
# 0  129   Diabetes      Cardiovascular        NaN               glaucoma
# 1  143   Diabetes      Cardiovascular        NaN                  ictus
# 2  137   Diabetes  Cirugia y Diabetes        NaN                cirugía
# 3  138   Diabetes  Cirugia y Diabetes        NaN  reducción de estómago
# 4    1   Diabetes            Diabetes        NaN               diabetes
#
#   keyword2  keyword3  keyword4 keyword5  \
# 0      NaN       NaN       NaN      NaN
# 1      NaN       NaN       NaN      NaN
# 2      NaN       NaN       NaN      NaN
# 3      NaN       NaN       NaN      NaN
# 4      NaN       NaN       NaN      NaN
#
#                                             Pregunta  \
# 0      Quisiera saber acerca de glaucoma y diabetes.
# 1  ¿los diabeticos tienes más posibilidades de te...
# 2      ¿En qué consiste la cirugía para la diabetes?
# 3  ¿Una persona que decida realizarse una operaci...
# 4                               ¿Qué es la Diabetes?
#
#                                            Respuesta             Fuente
# 0  El glaucoma es un grupo de enfermedades que pu...        nei.nih.gov
# 1  Los pacientes con diabetes tienen mayor riesgo...  fundacioictus.com
# 2  Consiste en la cirugía de bypass gástrico Redu...       diabetes.org
# 3  A veces se considera a la cirugía bariátrica c...       diabetes.org
# 4  Es una Enfermedad crónica que se produce cuand...            idf.org

# %%
pares = []
for index, row in df1.iterrows():
    # recorrer cada columna keyword
    for k in range(1, max_keys+1):
        keyword = row['keyword'+str(k)]
        if type(keyword) == str:
            for lab_idx in range(1, max_labels+1):
                label = row['Etiqueta '+str(lab_idx)]
                if type(label) == str:
                    pares.append([label, keyword])
print pares[0:10]
# Out:
# [['Diabetes', 'glaucoma'], ['Cardiovascular', 'glaucoma'], ['Diabetes', 'ictus'], ['Cardiovascular', 'ictus'], ['Diabetes', 'cirug\xc3\xada'], ['Cirugia y Diabetes', 'cirug\xc3\xada'], ['Diabetes', 'reducci\xc3\xb3n de est\xc3\xb3mago'], ['Cirugia y Diabetes', 'reducci\xc3\xb3n de est\xc3\xb3mago'], ['Diabetes', 'diabetes'], ['Diabetes', 'diabetes']]

# %%
import codecs, json
data = {
    "diabetes": pares
}
if gen_etiquetas:
    with open('etiquetas_db.json', 'w') as f:
        json.dump(data, f, ensure_ascii=False, sort_keys = True)#, indent = 4)
else:
    print("No se guarda archivo de etiquetas")
# Out:
# No se guarda archivo de etiquetas

# %% [markdown]
# ### 2. Sinónimos con w2v

# %%
df1.head()
# Out:
#     2q Etiqueta 1          Etiqueta 2 Etiqueta 3               keyword1  \
# 0  129   Diabetes      Cardiovascular        NaN               glaucoma
# 1  143   Diabetes      Cardiovascular        NaN                  ictus
# 2  137   Diabetes  Cirugia y Diabetes        NaN                cirugía
# 3  138   Diabetes  Cirugia y Diabetes        NaN  reducción de estómago
# 4    1   Diabetes            Diabetes        NaN               diabetes
#
#   keyword2  keyword3  keyword4 keyword5  \
# 0      NaN       NaN       NaN      NaN
# 1      NaN       NaN       NaN      NaN
# 2      NaN       NaN       NaN      NaN
# 3      NaN       NaN       NaN      NaN
# 4      NaN       NaN       NaN      NaN
#
#                                             Pregunta  \
# 0      Quisiera saber acerca de glaucoma y diabetes.
# 1  ¿los diabeticos tienes más posibilidades de te...
# 2      ¿En qué consiste la cirugía para la diabetes?
# 3  ¿Una persona que decida realizarse una operaci...
# 4                               ¿Qué es la Diabetes?
#
#                                            Respuesta             Fuente
# 0  El glaucoma es un grupo de enfermedades que pu...        nei.nih.gov
# 1  Los pacientes con diabetes tienen mayor riesgo...  fundacioictus.com
# 2  Consiste en la cirugía de bypass gástrico Redu...       diabetes.org
# 3  A veces se considera a la cirugía bariátrica c...       diabetes.org
# 4  Es una Enfermedad crónica que se produce cuand...            idf.org

# %%
from gensim import models

w2v_path = '/media/Tera/Datasets/NLP/sbw_vectors.bin'
w = models.KeyedVectors.load_word2vec_format(w2v_path, binary=True)
print("Datos word2vec cargados")
# Out:
# Datos word2vec cargados

# %%
# numero de columnas keyword ya encontrado antes
print("Cantidad de columnas con keywords_df: {}\n".format(max_keys))
# guardar todos los keyword
keywords = []
for index, row in df1.iterrows():
    for k in range(1, max_keys+1):
        keyword = row['keyword'+str(k)]
        if type(keyword) == str and keyword not in keywords:
            keywords.append(keyword)
print keywords
# Out:
# Cantidad de columnas con keywords_df: 5
#
# ['glaucoma', 'ictus', 'cirug\xc3\xada', 'reducci\xc3\xb3n de est\xc3\xb3mago', 'diabetes', 'complicaciones', 'retinopat\xc3\xada', 'glucosa', 'tolerancia a la glucosa', 'caramelos', 'insulina', 'ejercicio', 'evitar', 'embarazar', 'splenda', 'az\xc3\xbacar', 'licor', 'alimentos', 'fruta', 'dulces', 'erecci\xc3\xb3n', 'dentales', 'predisponen', 'predispone', 'diagnostica', 'diagnosticar', 'diabetes gestacional', 'embarazo', 'bebe', 'embarazada', 'gestaci\xc3\xb3n', 'tipo 1', 'tipo I', 'tipo 2', 'tipo II', 'corro', 'correr', '\xc3\xb3sea', 'huesos', 'enc\xc3\xadas', 'enc\xc3\xada', 'insulinemia', 'Hemoglobina Glicosilada', 'HbA1c', 'Que es la A1c', 'erectil', 'sexuales', 'sexual', 'deporte', 'Hipoglicemia', 'Hipoglicemia Asintomatico', 'Hipoglicemia Asintomatica', 'nefropatia', 'neuropat\xc3\xada', 'neuropat\xc3\xadas', 'obesidad', 'obeso', 'periodoncia', 'pie diab\xc3\xa9tico', 'piel', 'Dermopatia Diabetica', 'Necrobiosis lipoidica', 'prediabetes', 'Metfornina', 'Glibenclamida', 'Insulina', 'Glucagon', 'Ampollas diabeticas', 'xantomatosis eruptiva', 'Ti\xc3\xb1a inguinal', 'pie de atleta', 'Ti\xc3\xb1a', 'infecciones vaginales', 'Acantosis Nigricans', 'esclerosis digital', 'ampollas diabeticas', 'Granuloma anular', 'ojo', 'ojos', 'cataratas', 'catarata', 'Retinopa\xc3\xada Diab\xc3\xa9tica', 'Edema Macular', 'Fotocoagulacion', 'edema macular', 'prevenir', 'prevenci\xc3\xb3n', 'Chile', 'poblaci\xc3\xb3n', 'Mexico', 'cetoacidosis', '\xc3\xadndice gluc\xc3\xa9mico', 'sacarina', 'comer', 'sacarosa', 'pre diabetes']

# %%
sinonimos = []
for keyword in keywords:
    knn = [keyword]
    try:
        for x in w.most_similar(keyword.decode('utf-8'), topn=5):
            knn.append(x[0])
    except:
        print("{} no existe en vocabulario".format(keyword))
    sinonimos.append(knn)
sinonimos = pd.DataFrame(sinonimos)
sinonimos.sample(5)
# Out:
# reducción de estómago no existe en vocabulario
# tolerancia a la glucosa no existe en vocabulario
# diabetes gestacional no existe en vocabulario
# tipo 1 no existe en vocabulario
# tipo I no existe en vocabulario
# tipo 2 no existe en vocabulario
# tipo II no existe en vocabulario
# insulinemia no existe en vocabulario
# Hemoglobina Glicosilada no existe en vocabulario
# HbA1c no existe en vocabulario
# Que es la A1c no existe en vocabulario
# Hipoglicemia no existe en vocabulario
# Hipoglicemia Asintomatico no existe en vocabulario
# Hipoglicemia Asintomatica no existe en vocabulario
# nefropatia no existe en vocabulario
# pie diabético no existe en vocabulario
# Dermopatia Diabetica no existe en vocabulario
# Necrobiosis lipoidica no existe en vocabulario
# Metfornina no existe en vocabulario
# Glibenclamida no existe en vocabulario
# Glucagon no existe en vocabulario
# Ampollas diabeticas no existe en vocabulario
# xantomatosis eruptiva no existe en vocabulario
# Tiña inguinal no existe en vocabulario
# pie de atleta no existe en vocabulario
# infecciones vaginales no existe en vocabulario
# Acantosis Nigricans no existe en vocabulario
# esclerosis digital no existe en vocabulario
# ampollas diabeticas no existe en vocabulario
# Granuloma anular no existe en vocabulario
# Retinopaía Diabética no existe en vocabulario
# Edema Macular no existe en vocabulario
# Fotocoagulacion no existe en vocabulario
# edema macular no existe en vocabulario
# índice glucémico no existe en vocabulario
# pre diabetes no existe en vocabulario
#                             0         1           2             3  \
# 47                     sexual  sexuales  sexualidad  sexualDIGITO
# 28                       bebe     beben       beber    emborracha
# 50  Hipoglicemia Asintomatico      None        None          None
# 44              Que es la A1c      None        None          None
# 26       diabetes gestacional      None        None          None
#
#               4           5
# 47  sexualmente  efebofilia
# 28        bebió        beba
# 50         None        None
# 44         None        None
# 26         None        None

# %%
# maybe output
if gen_sinonimos:
    sinonimos.to_csv('sinonimos_w2v_parciales.csv', encoding='utf-8', header=None, index=None)
else:
    print("No se guarda archivo de sinonimos")

# %% [markdown]
# ### 3. Árbol de etiquetas

# %%
df1.head()
# Out:
#     2q Etiqueta 1          Etiqueta 2 Etiqueta 3               keyword1  \
# 0  129   Diabetes      Cardiovascular        NaN               glaucoma
# 1  143   Diabetes      Cardiovascular        NaN                  ictus
# 2  137   Diabetes  Cirugia y Diabetes        NaN                cirugía
# 3  138   Diabetes  Cirugia y Diabetes        NaN  reducción de estómago
# 4    1   Diabetes            Diabetes        NaN               diabetes
#
#   keyword2  keyword3  keyword4 keyword5  \
# 0      NaN       NaN       NaN      NaN
# 1      NaN       NaN       NaN      NaN
# 2      NaN       NaN       NaN      NaN
# 3      NaN       NaN       NaN      NaN
# 4      NaN       NaN       NaN      NaN
#
#                                             Pregunta  \
# 0      Quisiera saber acerca de glaucoma y diabetes.
# 1  ¿los diabeticos tienes más posibilidades de te...
# 2      ¿En qué consiste la cirugía para la diabetes?
# 3  ¿Una persona que decida realizarse una operaci...
# 4                               ¿Qué es la Diabetes?
#
#                                            Respuesta             Fuente
# 0  El glaucoma es un grupo de enfermedades que pu...        nei.nih.gov
# 1  Los pacientes con diabetes tienen mayor riesgo...  fundacioictus.com
# 2  Consiste en la cirugía de bypass gástrico Redu...       diabetes.org
# 3  A veces se considera a la cirugía bariátrica c...       diabetes.org
# 4  Es una Enfermedad crónica que se produce cuand...            idf.org

# %%
# maximo de recursion
import sys
sys.setrecursionlimit(5)

# generar data de relaciones de nodos
nodos_list = []
for i, row in df1.iterrows():
    for j in range(1, max_labels+1):
        # seguir solo si la celda contiene algo
        if type(row['Etiqueta '+str(j)]) == str:
            name = row['Etiqueta '+str(j)]
            if j == 1:
                parent = None
            else:
                parent = row['Etiqueta '+str(j-1)]
            node = { 
                'name': name,
                'parent': parent
            }
            if node not in nodos_list:
                nodos_list.append(node)
        else:
            continue
#print nodos_list  

def pop_list(nodes=None, parent=None, tree=None):
    if parent is None:
        return tree
    tree.append([])
    for node in nodes:
        if node['parent'] == parent:
            tree[-1].append(node)
        if node['name'] == parent:
            next_parent = node['parent']
            print next_parent
    pop_list(nodes, next_parent, tree)
    return tree

tree = []
print pop_list(nodos_list, "Diabetes", tree)
